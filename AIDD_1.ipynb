# %% [markdown]
# # Python 基础

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 1. 加、减、乘、除、余、平方

# %%
1+1
# Out:
# 2

# %%
5-4
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
6/4
# Out:
# 1.5

# %%
10%3
# Out:
# 1

# %%
4**2
# Out:
# 16

# %% [markdown]
# ## 2. 变量、几种常见类型
# * int
# * float
# * str
# * bool

# %%
teach = 5

# %%
teach
# Out:
# 5

# %%
type(teach)
# Out:
# int

# %%
teach=2.5

# %%
type(teach)
# Out:
# float

# %%
teach="2.5"

# %%
type(teach)
# Out:
# str

# %%
teach = False

# %%
type(teach)
# Out:
# bool

# %% [markdown]
# ## 3. 类型转换

# %%
teach="2.5"

# %%
teach
# Out:
# '2.5'

# %%
float(teach)
# Out:
# 2.5

# %% [markdown]
# ## 4. 字符串 str

# %%
teach = "2.5"

# %%
teach * 2
# Out:
# '2.52.5'

# %%
float(teach) * 2
# Out:
# 5.0

# %%
a="Hello"; b="World"

# %%
teach = a+b

# %%
teach
# Out:
# 'HelloWorld'

# %%
len(teach)
# Out:
# 10

# %%
teach="a b c d e"

# %%
len(teach)
# Out:
# 9

# %%
teach.split()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# ## 5. 列表 list

# %%
teach = [1, 3, 2, 5, 4]

# %%
teach
# Out:
# [1, 3, 2, 5, 4]

# %%
teach[3]
# Out:
# 5

# %%
teach.sort()

# %%
teach
# Out:
# [1, 2, 3, 4, 5]

# %%
teach.append(6)

# %%
teach
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
teach.remove(4)

# %%
teach
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# ## 6. 字典 dict

# %%
teach_dict={"xiaoming": 65,"xiaohong": 85, "xiaohei": 59}

# %%
teach_dict["xiaoming"]
# Out:
# 65

# %%
teach_dict["xiaoming"] = 70

# %%
teach_dict
# Out:
# {'xiaoming': 70, 'xiaohong': 85, 'xiaohei': 59}

# %%
teach_dict.keys()
# Out:
# dict_keys(['xiaoming', 'xiaohong', 'xiaohei'])

# %%
teach_dict.values()
# Out:
# dict_values([70, 85, 59])

# %% [markdown]
# ## 7. 集合 set

# %%
teach=[1,1,2,2,3,3,4]

# %%
teach
# Out:
# [1, 1, 2, 2, 3, 3, 4]

# %%
set(teach)
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3,4,5}

# %%
b={3,4,5,6,7}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a|b
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a.intersection(b)
# Out:
# {3, 4, 5}

# %%
a&b
# Out:
# {3, 4, 5}

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
a-b
# Out:
# {1, 2}

# %%
b-a
# Out:
# {6, 7}

# %%
c=b-a

# %%
c
# Out:
# {6, 7}

# %%
c.issubset(a)
# Out:
# False

# %%
c.issubset(b)
# Out:
# True

# %%
a.remove(5)

# %%
a
# Out:
# {1, 2, 3, 4}
